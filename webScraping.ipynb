# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging

# %%
flipkart_url="https://www.flipkart.com/search?q="+"tv"

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=tv'

# %%
urlclient=urlopen(flipkart_url)

# %%
flipkart_page=urlclient.read()

# %%
flipkart_html=bs(flipkart_page,'html.parser')

# %%
"https://www.flipkart.com" +"/mi-5a-80-cm-32-inch-hd-ready-led-smart-android-tv-dolby-audio-2022-model/p/itm98501ffa297ba?pid=TVSGD5CS2SDUUZGN&lid=LSTTVSGD5CS2SDUUZGNPVJDFV&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_1&otracker=search&otracker1=search&fm=Search&iid=en_sR6g3z38txGXgfwX%2FMunaKPvRuBTiBkSbyVVHthQA%2FpbMuWRxbMdYr%2BQJHDdkK0827Q6kbVOJAZv9zebPTyvxQ%3D%3D&ppt=sp&ppn=sp&qH=c9a1fdac6e082dd8"
# Out:
# 'https://www.flipkart.com/mi-5a-80-cm-32-inch-hd-ready-led-smart-android-tv-dolby-audio-2022-model/p/itm98501ffa297ba?pid=TVSGD5CS2SDUUZGN&lid=LSTTVSGD5CS2SDUUZGNPVJDFV&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_1&otracker=search&otracker1=search&fm=Search&iid=en_sR6g3z38txGXgfwX%2FMunaKPvRuBTiBkSbyVVHthQA%2FpbMuWRxbMdYr%2BQJHDdkK0827Q6kbVOJAZv9zebPTyvxQ%3D%3D&ppt=sp&ppn=sp&qH=c9a1fdac6e082dd8'

# %%
bigbox=flipkart_html.find_all("div",{"class":"_1AtVbE col-12-12"})

# %%
len(bigbox)
# Out:
# 30

# %%
del bigbox[0:2]

# %%
product_link='https://www.flipkart.com'+bigbox[0].div.div.div.a['href']

# %%
for i in bigbox:
    print('https://www.flipkart.com'+i.div.div.div.a['href'])
# Out:
# https://www.flipkart.com/mi-5a-80-cm-32-inch-hd-ready-led-smart-android-tv-dolby-audio-2022-model/p/itm98501ffa297ba?pid=TVSGD5CS2SDUUZGN&lid=LSTTVSGD5CS2SDUUZGNPVJDFV&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_1&otracker=search&fm=organic&iid=en_gNeqqNotbKcwxhDJdRgWb1oEfrAB%2B5K%2Bffj1b5FWwWi8fc7q1PXsR1DJXcaDJesb27Q6kbVOJAZv9zebPTyvxQ%3D%3D&ppt=None&ppn=None&ssid=ap6wl21i9s0000001685301722783&qH=c9a1fdac6e082dd8
# https://www.flipkart.com/motorola-envision-80-cm-32-inch-hd-ready-led-smart-android-tv-11-bezel-less-design-dolby-audio-2023/p/itm5a06cfa39ea7f?pid=TVSGNSUEAPVVWGHP&lid=LSTTVSGNSUEAPVVWGHPXRFOAU&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_2&otracker=search&fm=organic&iid=en_gNeqqNotbKcwxhDJdRgWb1oEfrAB%2B5K%2Bffj1b5FWwWgF%2BbREqFmhVYjmBpOb2S%2FTFiVUyb9asrVJZBNyYV2NMg%3D%3D&ppt=None&ppn=None&ssid=ap6wl21i9s0000001685301722783&qH=c9a1fdac6e082dd8
# ...

# %%
product_link
# Out:
# 'https://www.flipkart.com/mi-5a-80-cm-32-inch-hd-ready-led-smart-android-tv-dolby-audio-2022-model/p/itm98501ffa297ba?pid=TVSGD5CS2SDUUZGN&lid=LSTTVSGD5CS2SDUUZGNPVJDFV&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_1&otracker=search&fm=organic&iid=en_gNeqqNotbKcwxhDJdRgWb1oEfrAB%2B5K%2Bffj1b5FWwWi8fc7q1PXsR1DJXcaDJesb27Q6kbVOJAZv9zebPTyvxQ%3D%3D&ppt=None&ppn=None&ssid=ap6wl21i9s0000001685301722783&qH=c9a1fdac6e082dd8'

# %%
product_req=requests.get(product_link)

# %%
product_html=bs(product_req.text,'html.parser')

# %%
product_html
# Out:
# <!DOCTYPE html>
# ...

# %%
comment_box=product_html.find_all("div",{"class":"_16PBlm"})

# %%
len(comment_box)
# Out:
# 11

# %%
comment_box[0].div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text
# Out:
# 'nishant yadav'

# %%
for i in comment_box:
    print(i.div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text)
# Out:
# nishant yadav
# shabab khan
# sai kumar
# Deepak Rai
# Flipkart Customer
# Flipkart Customer
# SANTHOSH PILLALAMARRI
# RAJESH HEGDE
# MANISH THAKURDESAI
# Shobhit Saxena
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14036\3047202390.py in <module>
#       1 for i in comment_box:
# ----> 2     print(i.div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment_box[0].div.div.div.div.text
# Out:
# '5'

# %%
for i in comment_box:
    print(i.div.div.div.div.text)
# Out:
# 5
# 5
# 5
# 4
# 4
# 4
# 5
# 5
# 5
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14036\2621339938.py in <module>
#       1 for i in comment_box:
# ----> 2     print(i.div.div.div.div.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment_box[0].div.div.div.p.text
# Out:
# 'Terrific purchase'

# %%
for i in comment_box:
    print(i.div.div.div.p.text)
# Out:
# Terrific purchase
# Mind-blowing purchase
# Awesome
# Very Good
# Delightful
# Nice product
# Terrific
# Highly recommended
# Highly recommended
# Excellent
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14036\4044681715.py in <module>
#       1 for i in comment_box:
# ----> 2     print(i.div.div.div.p.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'
